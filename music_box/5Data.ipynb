# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
schema = ['uid','device','song_id','song_type','song_name','singer','play_time','song_length','paid_flag','file_name','label', 'date']

# %%
df_play = pd.read_csv('/Users/ZhijingYe/Desktop/data/output/play_sample_log.csv',
                 delimiter='\t',index_col=False,
                 dtype = {'uid':'str', 'song_id':'str','song_type' : 'str'})
# Out:
# /Users/ZhijingYe/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1159: DtypeWarning: Columns (9,10,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
df_play.head()
# Out:
#    Unnamed: 0  index        uid device   song_id song_type    song_name  \
# 0           0      0  168308107     ar    162455         0        最初的梦想
# 1           1      1  168112765     ar   4393501         0  喜欢你(f101 粤)
# 2           2      2  168274411     ar  22833011         0           宽恕
# 3           3      3          0     ar   4266814         1        天使的翅膀
# 4           4      4  168274411     ar    176292         0         爱不爱我
#
#    singer play_time song_length paid_flag            file_name label      date
# 0     范玮琪       296         296         0  20170410_2_play.log     0  20170410
# 1  Beyond       272           0         0  20170410_2_play.log     0  20170410
# 2    宽恕乐队        24         156         0  20170410_2_play.log     0  20170410
# 3     徐誉滕    214384           0         0  20170410_2_play.log     0  20170410
# 4    零点乐队       333         334         0  20170410_2_play.log     0  20170410

# %%
df_play = df_play.drop(df_play.columns[0], axis=1)
df_play.head()
# Out:
#    index        uid device   song_id song_type    song_name  singer play_time  \
# 0      0  168308107     ar    162455         0        最初的梦想     范玮琪       296
# 1      1  168112765     ar   4393501         0  喜欢你(f101 粤)  Beyond       272
# 2      2  168274411     ar  22833011         0           宽恕    宽恕乐队        24
# 3      3          0     ar   4266814         1        天使的翅膀     徐誉滕    214384
# 4      4  168274411     ar    176292         0         爱不爱我    零点乐队       333
#
#   song_length paid_flag            file_name label      date
# 0         296         0  20170410_2_play.log     0  20170410
# 1           0         0  20170410_2_play.log     0  20170410
# 2         156         0  20170410_2_play.log     0  20170410
# 3           0         0  20170410_2_play.log     0  20170410
# 4         334         0  20170410_2_play.log     0  20170410

# %%
df_play = df_play.drop(df_play.columns[0], axis=1)
df_play.head()
# Out:
#          uid device   song_id song_type    song_name  singer play_time  \
# 0  168308107     ar    162455         0        最初的梦想     范玮琪       296
# 1  168112765     ar   4393501         0  喜欢你(f101 粤)  Beyond       272
# 2  168274411     ar  22833011         0           宽恕    宽恕乐队        24
# 3          0     ar   4266814         1        天使的翅膀     徐誉滕    214384
# 4  168274411     ar    176292         0         爱不爱我    零点乐队       333
#
#   song_length paid_flag            file_name label      date
# 0         296         0  20170410_2_play.log     0  20170410
# 1           0         0  20170410_2_play.log     0  20170410
# 2         156         0  20170410_2_play.log     0  20170410
# 3           0         0  20170410_2_play.log     0  20170410
# 4         334         0  20170410_2_play.log     0  20170410

# %%
df_play.isnull().sum(axis = 0)
# Out:
# uid                0
# device             0
# song_id            0
# song_type          0
# song_name        205
# singer         37715
# play_time          0
# song_length        0
# paid_flag          0
# file_name          0
# label              0
# date               0
# dtype: int64

# %% [markdown]
# ### 1. file_name and paid_flag
# First drop file_name and paid_flag columns.
#
# (a) there is a column 'date' contains log date information <br>
# (b) In data cleaning file, we noticed there is no real paid users so this columns can be dropped

# %%
df_play = df_play.drop(['paid_flag', 'file_name'], axis=1)

# %%
df_play.head()
# Out:
#          uid device   song_id song_type    song_name  singer play_time  \
# 0  168308107     ar    162455         0        最初的梦想     范玮琪       296
# 1  168112765     ar   4393501         0  喜欢你(f101 粤)  Beyond       272
# 2  168274411     ar  22833011         0           宽恕    宽恕乐队        24
# 3          0     ar   4266814         1        天使的翅膀     徐誉滕    214384
# 4  168274411     ar    176292         0         爱不爱我    零点乐队       333
#
#   song_length label      date
# 0         296     0  20170410
# 1           0     0  20170410
# 2         156     0  20170410
# 3           0     0  20170410
# 4         334     0  20170410

# %%
df_play.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39492326 entries, 0 to 39492325
# Data columns (total 10 columns):
# uid            object
# device         object
# song_id        object
# song_type      object
# song_name      object
# singer         object
# play_time      object
# song_length    object
# label          object
# date           object
# dtypes: object(10)
# memory usage: 3.2+ GB

# %% [markdown]
# ### 2. uid

# %%
df_play.uid.value_counts()
# Out:
# 1685126      7539141
# 751824       4409667
# 0            1158075
# 1679121       480214
# 32166203      141050
# 16517426       73648
# 1791497        33003
# 168353633      31528
# 45365429       24726
# 168930795      22000
# 168511018      18451
# 168778891      17915
# 168458969      17540
# 168680315      17224
# 168884001      16927
# ...
# 168567540     1
# 168446265     1
# 168589266     1
# 168739286     1
# 168770296     1
# 154513544     1
# 167684079     1
# 168874875     1
# 154656556     1
# 168974365     1
# 154735788     1
# 167759192     1
# 168827374     1
# 168797163     1
# 168374791     1
# Length: 150866, dtype: int64

# %% [markdown]
# #### There are some users have way more than usual number of logs.
# #### Say one log takes one min, there are 24*60 = 1440 mins per day. Thoes uses have more than 1440 logs per date should be robots.

# %%
res = df_play[['uid','date','song_id']].groupby(['uid','date']).count().rename(columns={'song_id': 'count'})

# %%
res.reset_index()
# Out:
#               uid      date  count
# 0               0         0     50
# 1               0  20170330   3132
# 2               0  20170331  12003
# 3               0  20170401  16158
# 4               0  20170402  21429
# 5               0  20170403  10973
# 6               0  20170404  17208
# 7               0  20170405  13773
# 8               0  20170406  13878
# 9               0  20170407  12765
# 10              0  20170408  14886
# 11              0  20170409  13893
# 12              0  20170410  14406
# 13              0  20170411  20754
# 14              0  20170412  75285
# 15              0  20170413  59274
# 16              0  20170414  31275
# 17              0  20170415  53163
# 18              0  20170416  35082
# 19              0  20170417  34032
# 20              0  20170418  33216
# 21              0  20170419  31197
# 22              0  20170420  26922
# 23              0  20170421  32214
# 24              0  20170422  34146
# 25              0  20170423  38619
# 26              0  20170424  15894
# 27              0  20170425  30525
# 28              0  20170426  27135
# 29              0  20170427  29582
# ...           ...       ...    ...
# 969677   99387196  20170508      6
# 969678   99387196  20170512      2
# 969679  99560754   20170339     49
# 969680   9963002   20170301      3
# 969681  99633829   20170301      5
# 969682  99633829   20170302     44
# 969683  99633829   20170303     31
# 969684  99633829   20170305    133
# 969685  99633829   20170307     26
# 969686  99633829   20170308     82
# 969687  99633829   20170309     12
# 969688   99689252  20170331    134
# 969689   99689252  20170401     10
# 969690   99689252  20170403     15
# 969691   99689252  20170420      2
# 969692   99689252  20170425      1
# 969693   99725077  20170330     12
# 969694   99725077  20170401     12
# 969695   99725077  20170405      1
# 969696   99725077  20170406      1
# 969697   99725077  20170423      2
# 969698  99983627   20170301      9
# 969699  99983627   20170303     11
# 969700  99983627   20170304     46
# 969701  99983627   20170305     53
# 969702  99983627   20170306      8
# 969703  99983627   20170307      7
# 969704  99983627   20170308      9
# 969705  99983627   20170309     16
# 969706  99995513   20170339      1
#
# [969707 rows x 3 columns]

# %%
res2 = res.reset_index()

# %%
res22 = res2.loc[res2.uid>0]

# %%
res22.head(10)
# Out:
#   uid      date  count
# 0   0         0     50
# 1   0  20170330   3132
# 2   0  20170331  12003
# 3   0  20170401  16158
# 4   0  20170402  21429
# 5   0  20170403  10973
# 6   0  20170404  17208
# 7   0  20170405  13773
# 8   0  20170406  13878
# 9   0  20170407  12765

# %%
#res1 = df_play.loc[df_play.uid > 0]

# %%
#res1.head(10)

# %%
#res.head(20)

# %%
#res1.tail(10)

# %%
res_agg = res22.groupby('uid')['count'].agg(['sum','count'])

# %%
res_agg.head()
# Out:
#                sum  count
# uid
# 0          1158075     45
# 100052111      112      1
# 100107633        4      1
# 100223381       16      2
# 100581940       20      1

# %%
res_agg['avg_logs'] = res_agg['sum']/res_agg['count']

# %%
res_agg.head()
# Out:
#                sum  count  avg_logs
# uid
# 0          1158075     45     25735
# 100052111      112      1       112
# 100107633        4      1         4
# 100223381       16      2         8
# 100581940       20      1        20

# %%
uid_robot = res_agg[res_agg['avg_logs'] > 1440].index

# %%
uid_robot
# Out:
# Index([u'0', u'154492987 ', u'16517426', u'1679121', u'168341300', u'1685126', u'168813477', u'1791497 ', u'32166203', u'46532274 ', u'751824'], dtype='object')

# %%
uid_robot = set(uid_robot)

# %%
uid_robot
# Out:
# {'0',
#  '154492987 ',
#  '16517426',
#  '1679121',
#  '168341300',
#  '1685126',
#  '168813477',
#  '1791497 ',
#  '32166203',
#  '46532274 ',
#  '751824'}

# %%
# Remove those suspecious robot users
df_play = df_play[~df_play['uid'].isin(uid_robot)]

# %%
df_play.shape
# Out:
# (25632738, 10)

# %%
del res22, res_agg

# %% [markdown]
# ### 3. Device type was already taken care in data cleansing step.

# %%
df_play.device.value_counts()
# Out:
# ar           21250314
# ip            4382423
# 168589573           1
# dtype: int64

# %% [markdown]
# ### 4. Date

# %%
df_play.groupby('date').size()
# Out:
# date
# 0               525
# 91                1
# 238               2
# 239               4
# 260              10
# 20170301     655949
# 20170302     446743
# 20170303     338692
# 20170304     292540
# 20170305     272102
# 20170306     236153
# 20170307     223694
# 20170308     210110
# 20170309     200251
# 20170330     893817
# 20170331    1244567
# 20170339     372350
# 20170401     998193
# 20170402     902918
# 20170403     514446
# 20170404     751377
# 20170405     646781
# 20170406     651936
# 20170407     645207
# 20170408     626827
# 20170409     624127
# 20170410     602120
# 20170411     359220
# 20170412     544443
# 20170413     529192
# 20170414     362888
# 20170415     535293
# 20170416     527866
# 20170417     485270
# 20170418     475435
# 20170419     466004
# 20170420     459969
# 20170421     459894
# 20170422     467222
# 20170423     459791
# 20170424     230999
# 20170425     422062
# 20170426     412376
# 20170427     460912
# 20170428     405889
# 20170429     419923
# 20170430     413245
# 20170501     396225
# 20170502     358705
# 20170503     365573
# 20170504     359843
# 20170505     351989
# 20170506     376023
# 20170507     376068
# 20170508     352797
# 20170509     354630
# 20170510     354877
# 20170511     351442
# 20170512     350049
# 20170410      35182
# Length: 60, dtype: int64

# %% [markdown]
# #### Convert date to string and remove the three outlier: 0, 168, 169, 238, 260

# %%
filter_date = set([0, 168, 169, 238, 260])

# %%
df_play = df_play[~df_play['date'].isin(filter_date)]

# %%
df_play['date'] = df_play['date'].astype('string')

# %%
df_play[['date']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25632201 entries, 0 to 39492325
# Data columns (total 1 columns):
# date    object
# dtypes: object(1)
# memory usage: 391.1+ MB

# %%
# Check the churn rate for different date
df_play.groupby(['date','label']).size()
# Out:
# date      label
# 20170301  1.0      310923
#           1        230991
#           1.0      114035
# 20170302  1.0      339748
#           1         77589
#           1.0       29406
# 20170303  1.0      183144
#           1        148588
#           1.0        6960
# 20170304  1.0      183745
#           1         77770
#           1.0       31025
# 20170305  1.0       88409
#           1        156555
#           1.0       27138
# ...
# 20170508  0.0       48319
# 20170509  0.0      111004
#           0        218403
#           0.0       25223
# 20170510  0.0      161909
#           0        170810
#           0.0       22158
# 20170511  0.0      194080
#           0        141738
#           0.0       15624
# 20170512  0.0      227654
#           0         48534
#           0.0       73861
# 239       0.0           4
# 91        186.0         1
# Length: 227, dtype: int64

# %% [markdown]
# #### 5. Song type

# %%
df_play.song_type.unique()
# Out:
# array(['0', '1', '2', '3', '0 ', '1 ', '2 ', '3 ', ' ',
#        '(112.12.76.97)TM ', '(110.187.207.110)TM ', '0(117.148.124.79)TM ',
#        '(117.149.87.208)TM ', '(39.183.144.65)TM ',
#        '0(117.174.249.184)TM ', '(111.75.125.50)TM ',
#        '2(117.87.25.173)TM ', '(39.187.201.177)TM ', '0(111.19.79.220)TM ',
#        '0(111.19.112.144)TM ', '0(117.68.67.125)TM ', '(42.243.53.92)TM ',
#        '(39.183.142.100)TM ', '0(101.27.25.233)TM ', '(111.2.101.131)TM ',
#        '0(39.189.228.228)TM ', '(223.94.194.28)TM ', '0(223.94.194.28)TM ',
#        '(112.11.81.170)TM ', '0(112.11.206.111)TM ', '(112.12.40.255)TM ',
#        '1(39.187.201.186)TM ', '(39.187.201.133)TM ',
#        '0(111.19.79.127)TM ', '0(112.11.85.53)TM ', '0(113.238.231.29)TM ',
#        '(39.174.89.218)TM ', '(112.11.206.128)TM ', '0(112.11.206.128)TM ',
#        '0(39.183.144.51)TM ', '(223.94.196.10)TM ', '(112.12.41.169)TM ',
#        '0(117.173.98.18)TM ', '0(182.246.211.72)TM ',
#        '0(39.186.100.19)TM ', '0(39.183.144.111)TM ', '0(39.174.92.81)TM ',
#        '(106.58.134.120)TM ', '(220.178.220.207)TM ', '0(112.11.3.219)TM ',
#        '1(222.87.59.40)TM ', '(222.87.59.40)TM ', '0(111.19.78.128)TM ',
#        '(117.149.49.16)TM ', '0(112.115.30.92)TM ', '(112.115.30.92)TM ',
#        '0(39.183.145.157)TM ', '(123.188.231.166)TM ',
#        '0(39.187.200.208)TM ', '0(39.189.229.9)TM ', '(39.183.145.67)TM ',
#        '0(111.19.78.47)TM '], dtype=object)

# %%
df_play.song_type = df_play.song_type.apply(lambda x: str(x).split('(')[0].rstrip())

# %%
df_play.song_type.value_counts()
# Out:
# 0    23090972
# 1     2306575
# 2      220015
#          9931
# 3        4708
# dtype: int64

# %%
# There are some missing values in song_type, impute with most common song_type 0
df_play.loc[df_play['song_type'] == '',['song_type']] = '0'

# %%
df_play.song_type.value_counts()
# Out:
# 0    23100903
# 1     2306575
# 2      220015
# 3        4708
# dtype: int64

# %% [markdown]
# #### 6. Label

# %%
df_play.label.value_counts()
# Out:
# 0        9141078
# 0.0      8300828
# 1.0      3244407
# 1        2591912
# 0.0      1734954
# 1.0       619021
# 186.0          1
# dtype: int64

# %%
# Convert label to int
df_play['label'] = df_play['label'].apply(lambda x: str(x).split('.')[0])

# %%
df_play.label.value_counts()
# Out:
# 0      19176860
# 1       6455340
# 186           1
# dtype: int64

# %% [markdown]
# #### 7. Play time

# %% [markdown]
# play_time are strings. Some are has '>' in it. Split with '>' and keep only the part in front of '>'.
#
# Then, change the type to float

# %%
df_play.play_time.value_counts()
# Out:
# 0      4334764
# 1       667976
# 0       486240
# 2       414224
# 3       300941
# 4       258415
# 5       205439
# 6       152632
# 7       130188
# 199     126478
# 249     122184
# 8       113005
# 231     111796
# 230     107546
# 248     106514
# ...
# 31118                       1
# 7>}(106.112.150.239)TM     1
# 130>(120.192.27.7)TM        1
# 53>=(117.135.227.169)TM     1
# 4>=(123.132.144.219)TM      1
# 4117                        1
# 390678                      1
# 23719                       1
# 0>=(119.125.76.233)TM       1
# 39067                       1
# 237198                      1
# 139055                      1
# 290259                      1
# 109.309070777               1
# 287144                      1
# Length: 244472, dtype: int64

# %%
df_play['play_time'] = df_play['play_time'].astype('string').apply(lambda x: x.split('>')[0])
df_play.play_time.value_counts()
# Out:
# 0      4350238
# 1       671876
# 0       486240
# 2       417428
# 3       303832
# 4       270279
# 5       239641
# 6       155150
# 7       131263
# 199     126594
# 249     122230
# 8       113857
# 231     111875
# 230     107613
# 248     106561
# ...
# 151696          1
# 108085          1
# 40113           1
# 0.057998138     1
# 42.156327242    1
# 69574           1
# 119887          1
# 17527           1
# 17525           1
# 162587          1
# 283699          1
# 93147           1
# 152288          1
# 152283          1
# 287144          1
# Length: 158371, dtype: int64

# %%
df_play['play_time'] = df_play['play_time'].convert_objects(convert_numeric= True)

# %%
df_play[['play_time']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25632201 entries, 0 to 39492325
# Data columns (total 1 columns):
# play_time    float64
# dtypes: float64(1)
# memory usage: 391.1 MB

# %% [markdown]
# #### 8. Song_id
# song_id should be an integer or a string of numbers without decimal
#
# The corner case is where song_id == '0'. There are more than 500k logs with '0' as song_id, but they
# are actually different songs:
#
#     Some songs have '0' and another song_id
#
#     Some songs only have '0' as song_id
#
# song_id imputation:
#
#     1) change the song_id to its most frequent appeared values, if there is value other than '0'
#
#     2) if it doesn't have another song_id, create new song_ids.
#
# What is needed is a {(song_name, singer, song_type):song_id} dictionary.

# %%
df_play.song_id = df_play.song_id.apply(lambda x: x.split('.')[0].rstrip())

# %%
df_play.loc[df_play.song_id == '0']
# Out:
#                 uid device song_id song_type  \
# 38        168412166     ar       0         1
# 39        168060257     ar       0         1
# 41        168429120     ar       0         1
# 49        168202184     ar       0         1
# 82        168412166     ar       0         1
# 101       168060257     ar       0         1
# 106       168429120     ar       0         1
# 112       168202184     ar       0         1
# 114       168508621     ar       0         1
# 122       168060257     ar       0         1
# 146       168412166     ar       0         1
# 181       168202184     ar       0         1
# 186       168060257     ar       0         1
# 187       168060257     ar       0         1
# 238       168202184     ar       0         1
# 239       168202184     ar       0         1
# 254       168448096     ar       0         1
# 318       168259730     ar       0         1
# 416       168408593     ar       0         1
# 506       168408593     ar       0         1
# 556       168408593     ar       0         1
# 573       168408593     ar       0         1
# 590       168408593     ar       0         1
# 644       168508621     ar       0         1
# 664       168408593     ar       0         1
# 678       168408593     ar       0         1
# 692       168408593     ar       0         1
# 716       168408593     ar       0         1
# 777       168408593     ar       0         1
# 817       168408593     ar       0         1
# ...             ...    ...     ...       ...
# 39488845  168471314     ar       0         1
# 39489020  168471314     ar       0         1
# 39489057  168160011     ar       0         1
# 39489061  168160011     ar       0         1
# 39489245  168059443     ar       0         1
# 39489760  168162099     ar       0         1
# 39489785  168471314     ar       0         1
# 39489829  168160011     ar       0         1
# 39489880  168362833     ar       0         1
# 39489905  168398789     ar       0         1
# 39489921  168248860     ar       0         1
# 39490317  168324382     ar       0         1
# 39490338  168138067     ar       0         1
# 39490424  168471314     ar       0         1
# 39490557  168162099     ar       0         1
# 39490604  168160011     ar       0         1
# 39490715  168471314     ar       0         1
# 39490724  168362833     ar       0         1
# 39490748  168517386     ar       0         1
# 39490864  168471314     ar       0         1
# 39490866  168138067     ar       0         1
# 39491183  168362833     ar       0         1
# 39491218  168120337     ar       0         1
# 39491222  168162099     ar       0         1
# 39491449  168138067     ar       0         1
# 39491819  168162099     ar       0         1
# 39491884  168324382     ar       0         1
# 39492034  168138067     ar       0         1
# 39492102  168378478     ar       0         1
# 39492111  168378478     ar       0         1
#
#                                                   song_name  \
# 38                                                       答案
# 39                                         小虾米 - 爱要逃(Live版)
# 41                                                       离别
# 49                                                     爸爸妈妈
# 82                                                答案 (Live)
# 101                                                云菲菲 - 殇雪
# 106                                          美丽的神话(《神话》主题曲)
# 112                                                    爸爸妈妈
# 114                                       冰河时代、Dj、舞曲 - 电子舞曲
# 122                                                    爸爸妈妈
# 146                                        带感越鼓（3D全景）-7妹+小可
# 181                                                    爸爸妈妈
# 186                                                      错爱
# 187                                             海生 - 情一动心就痛
# 238                                                    爸爸妈妈
# 239                                                    爸爸妈妈
# 254                                                    爱情促进
# 318                                                不做你幸福的玫瑰
# 416                    铃声多多_Delacey - Dream It Possible_许彦龙
# 506            铃声多多_Es Rappelt Im Karton 好听的英文歌_Pixie Paris
# 556              铃声多多_Flo Rida、Pitbull - Cant Believe it_Yg
# 573          铃声多多_GALA-Young For You(年轻) - 没错，这是中式英伦摇滚_GALA
# 590                    铃声多多_Gianni Kosta Belle - Sirius_AIA
# 644                                       冰河时代、Dj、舞曲 - 电子舞曲
# 664                         铃声多多_Honey Cocaine - Gwola_琛阿琛.
# 678                        铃声多多_I Am You - 英文女生声音很舒服铃声_网友上传
# 692       铃声多多_I m Just A Little Bit Shy - 很好听的英文歌_Natas...
# 716                    铃声多多_Jai Waetford - Shy 超好听_超好听的哦 。。
# 777                铃声多多_Kait Weston - I Just Wanna Run_野性酷女
# 817               铃声多多_Martin Tungevaag - Samsara 2016_Dj筱宇
# ...                                                     ...
# 39488845                                               等爱的人
# 39489020                                 Right+Here+Waiting
# 39489057                               A Little Forgiveness
# 39489061                               Call Your Girlfriend
# 39489245                                          薛之谦 - 刚刚好
# 39489760                                   Over the Horizon
# 39489785                                          03 我可以抱你吗
# 39489829                                              闹够了没有
# 39489880                                    G.E.M.邓紫棋 - 喜欢你
# 39489905                                         我只在乎你 (国语)
# 39489921                                         马旭东 - 入戏太深
# 39490317                                              挪威的森林
# 39490338                                               饿狼传说
# 39490424                                            03.忽然之间
# 39490557                                   Over the Horizon
# 39490604                                Twerk It Like Miley
# 39490715                                              04 苹果
# 39490724                        郝云 - 活着 - 2014光荣绽放十大中文金曲演唱会
# 39490748                                                一瞬间
# 39490864                                  12 BOTH SIDES NOW
# 39490866                                                凡人歌
# 39491183                                           黄勇 - 男人花
# 39491218                                               我不后悔
# 39491222                                   Over the Horizon
# 39491449                                                风中舞
# 39491819                                   Over the Horizon
# 39491884                                          练习 (Live)
# 39492034                                                刚刚好
# 39492102                                             就算没有如果
# 39492111                                             一个人的情歌
#
#                          singer  play_time song_length label      date
# 38                           杨坤        201         201     0  20170410
# 39                         未知歌手        216         217     0  20170410
# 41                           阿杜        229         230     0  20170410
# 49                           彭芳        268         268     0  20170410
# 82                       杨坤/郭采洁        200         201     0  20170410
# 101                        未知歌手        284         284     0  20170410
# 106                          孙楠        290         289     0  20170410
# 112                          彭芳        269         268     0  20170410
# 114                        未知歌手        188         188     0  20170410
# 122                        次仁旺堆         76          76     0  20170410
# 146                          7妹        283         284     0  20170410
# 181                          彭芳        267         268     0  20170410
# 186                         刘转亮        233         262     0  20170410
# 187                        未知歌手          0         232     0  20170410
# 238                          彭芳         85         268     0  20170410
# 239                          彭芳         85         268     0  20170410
# 254                        未知歌手       3767        3766     0  20170410
# 318                          红月        260         294     0  20170410
# 416                        未知歌手        165         165     0  20170410
# 506                        未知歌手        204         204     0  20170410
# 556                        未知歌手        112         113     0  20170410
# 573                        未知歌手         65          65     0  20170410
# 590                        未知歌手         60          61     0  20170410
# 644                        未知歌手        188         188     0  20170410
# 664                        未知歌手        226         226     0  20170410
# 678                        未知歌手         63          63     0  20170410
# 692                        未知歌手         61          61     0  20170410
# 716                        未知歌手         86          86     0  20170410
# 777                        未知歌手        189         189     0  20170410
# 817                        未知歌手        146         147     0  20170410
# ...                         ...        ...         ...   ...       ...
# 39488845                   未知歌手         35         304     0  20170429
# 39489020  Richard+Marx(理查德+马克思)         49         264     0  20170429
# 39489057            Christopher        207         227     0  20170429
# 39489061            Christopher          0         152     0  20170429
# 39489245                   未知歌手        145         250     0  20170429
# 39489760                Samsung        229         230     0  20170429
# 39489785                   未知歌手        230         232     0  20170429
# 39489829                    赖伟锋        238         238     0  20170429
# 39489880                   未知歌手        238         239     0  20170429
# 39489905                    邓丽君        210         252     0  20170429
# 39489921                   未知歌手         60         226     0  20170429
# 39490317        伍佰 & China Blue         14         223     0  20170429
# 39490338                     毒药        169         169     0  20170429
# 39490424                   未知歌手        200         202     0  20170429
# 39490557                Samsung        229         230     0  20170429
# 39490604           Brandon Beal         19         208     0  20170429
# 39490715                   未知歌手        123         274     0  20170429
# 39490724                   未知歌手        365         366     0  20170429
# 39490748                   丽江小倩        186         187     0  20170429
# 39490864                   未知歌手         61         304     0  20170429
# 39490866                     毒药        224         225     0  20170429
# 39491183                   未知歌手        310         310     0  20170429
# 39491218                     郑源        224         251     0  20170429
# 39491222                Samsung        229         230     0  20170429
# 39491449                  夏沐草乐队        271         271     0  20170429
# 39491819                Samsung        229         230     0  20170429
# 39491884                    刘德华        280         280     0  20170429
# 39492034                    薛之谦        250         250     0  20170429
# 39492102                     香香          7         305     0  20170429
# 39492111                     宝蓝          1         208     0  20170429
#
# [2079855 rows x 10 columns]

# %%
df_play.groupby(['song_name','singer','song_type']).size().shape
# Out:
# (1098757,)

# %%
df_play.groupby(['song_name','singer','song_type','song_id']).size().shape
# Out:
# (1196852,)

# %% [markdown]
# Although the combination of ('song_name','singer','song_type') can identify a song without ambiguity, there
# ISN'T an one-to-one mapping from ('song_name','singer','song_type') to 'song_id'.
#
# Find out the duplicated 'song_id's

# %%
df_play[['song_name']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25632201 entries, 0 to 39492325
# Data columns (total 1 columns):
# song_name    object
# dtypes: object(1)
# memory usage: 391.1+ MB

# %%
##df['song_name'] = df['song_name'].astype('str')

# %%
# Notice there are some empty spaces as inputs in song_name and singer, strip tailoring spaces
df_play[['song_name', 'singer']] = df_play[['song_name', 'singer']].applymap(lambda x: str(x).rstrip() if str(x) else x)

# %%
df_play.isnull().sum(axis = 0)
# Out:
# uid                0
# device             0
# song_id            0
# song_type          0
# song_name          0
# singer             0
# play_time      13794
# song_length        0
# label              0
# date               0
# dtype: int64

# %%
# Then remove the logs with nan song_name and singer, totally 58 logs
df_play = df_play.loc[df_play.song_name.notnull() & \
                      df_play.singer.notnull()]
df_play.isnull().sum(axis = 0)
# Out:
# uid                0
# device             0
# song_id            0
# song_type          0
# song_name          0
# singer             0
# play_time      13794
# song_length        0
# label              0
# date               0
# dtype: int64

# %%
# Count number of logs groupped by song_name, singer and song_type 
song_id_groupby_df = df_play[['song_name','singer','song_type','song_id']]\
                        .groupby(['song_name','singer','song_type']).count().rename(columns={'song_id': 'count'})

# %%
# make new song_id with the play times rank, where more played song is ranked as 1st.
song_id_groupby_df['song_id_new'] = song_id_groupby_df['count'].rank(method = 'first', ascending = False).astype('int')

# %%
song_id_groupby_df.reset_index(inplace = True)

# %%
song_id_groupby_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 911029 entries, 0 to 911028
# Data columns (total 5 columns):
# song_name      911029 non-null object
# singer         911029 non-null object
# song_type      911029 non-null object
# count          911029 non-null int64
# song_id_new    911029 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 41.7+ MB

# %%
song_id_groupby_df.head(10)
# Out:
#   song_name               singer song_type  count  song_id_new
# 0                                        0    998         3405
# 1                                        1     11       178668
# 2                                        2     28        90253
# 3                            2PM         1      2       461704
# 4                   Adam Lambert         0      1       607636
# 5                    Kari Kimmel         1      1       607637
# 6                           MC晓九         1      5       292737
# 7                           Mc小杨         0      1       607638
# 8                           Mc小洋         0      1       607639
# 9            Nur Mahammat Tursun         1      2       461705

# %%
song_id_groupby_df.loc[2, 'song_name']
# Out:
# ''

# %%
# Merge new_song_id to create a new dataframe
df_play_log = pd.merge(df_play, song_id_groupby_df,  how='left', \
                       left_on=['song_name','singer','song_type'], \
                       right_on = ['song_name','singer','song_type'])

# %%
df_play_log.head()
# Out:
#          uid device   song_id song_type    song_name  singer  play_time  \
# 0  168308107     ar    162455         0        最初的梦想     范玮琪        296
# 1  168112765     ar   4393501         0  喜欢你(f101 粤)  Beyond        272
# 2  168274411     ar  22833011         0           宽恕    宽恕乐队         24
# 3  168274411     ar    176292         0         爱不爱我    零点乐队        333
# 4  168274411     ar  22833011         0           宽恕    宽恕乐队        155
#
#   song_length label      date  count  song_id_new
# 0         296     0  20170410   3309          816
# 1           0     0  20170410    264        13121
# 2         156     0  20170410     16       140473
# 3         334     0  20170410   2559         1171
# 4         156     0  20170410     16       140473

# %%
df_play_log.shape, df_play.shape
# Out:
# ((25632201, 12), (25632201, 10))

# %%
df_play_log['song_id_new'].isnull().sum()
# Out:
# 0

# %%
# get favorite songs info
popular_songs = df_play_log['song_id_new'].value_counts()[:200].index

popular_songs[100:110]
# Out:
# Int64Index([101, 102, 103, 104, 105, 106, 107, 108, 109, 110], dtype='int64')

# %%
# the rarely played songs are also worth examining.
rarely_played = sum(df_play_log['song_id'].value_counts()<2)
rarely_played
# Out:
# 225313

# %%
rarely_played_songs = df_play_log.song_id_new.value_counts()[-1:-rarely_played-1:-1].index
len(rarely_played_songs)
# Out:
# 225313

# %%
# searching play log of a certain rare song
df_play_log[df_play_log.song_id_new == rarely_played_songs[0]]
# Out:
#                uid device  song_id song_type song_name singer  play_time  \
# 2716020  168428214     ar  5198255         0       不想你     唐尼         97
#
#         song_length label      date  count  song_id_new
# 2716020         199     0  20170409      1       712349

# %%
song_id_groupby_df[song_id_groupby_df.song_id_new == rarely_played_songs[0]]
# Out:
#        song_name singer song_type  count  song_id_new
# 279635       不想你     唐尼         0      1       712349

# %% [markdown]
# ### 9.singer

# %%
singer_groupby_df = df_play[['singer','song_id']]\
                   .groupby(['singer']).count().rename(columns={'song_id': 'count'})

# %%
singer_groupby_df.reset_index(inplace = True)
singer_groupby_df.head()
# Out:
#                  singer  count
# 0                         8131
# 1                 伦桑      1
# 2  ♫°﹎满汉全席丶伦　桑『满汉の歌手』      1
# 3  ♫°﹎满汉全席丶妄　尘『古风の歌手』      1
# 4  ♫°﹎满汉全席丶宁采臣『满汉の歌手』      1

# %%
singer_groupby_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109640 entries, 0 to 109639
# Data columns (total 2 columns):
# singer    109640 non-null object
# count     109640 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 2.5+ MB

# %%
singer_groupby_df['singer_popularity_rank'] = singer_groupby_df[['count']].rank(method = 'first', ascending = False).astype(int)

# %%
singer_groupby_df.head()
# Out:
#                  singer  count  singer_popularity_rank
# 0                         8131                     486
# 1                 伦桑      1                   82954
# 2  ♫°﹎满汉全席丶伦　桑『满汉の歌手』      1                   82955
# 3  ♫°﹎满汉全席丶妄　尘『古风の歌手』      1                   82956
# 4  ♫°﹎满汉全席丶宁采臣『满汉の歌手』      1                   82957

# %%
# Merge singer_popularity to create a new dataframe
df_play_log = pd.merge(df_play_log, singer_groupby_df,  how='left', \
                       left_on=['singer'], \
                       right_on = ['singer'])

# %%
df_play_log.head()
# Out:
#          uid device   song_id song_type    song_name  singer  play_time  \
# 0  168308107     ar    162455         0        最初的梦想     范玮琪        296
# 1  168112765     ar   4393501         0  喜欢你(f101 粤)  Beyond        272
# 2  168274411     ar  22833011         0           宽恕    宽恕乐队         24
# 3  168274411     ar    176292         0         爱不爱我    零点乐队        333
# 4  168274411     ar  22833011         0           宽恕    宽恕乐队        155
#
#   song_length label      date  count_x  song_id_new  count_y  \
# 0         296     0  20170410     3309          816    20427
# 1           0     0  20170410      264        13121   100771
# 2         156     0  20170410       16       140473       25
# 3         334     0  20170410     2559         1171     9263
# 4         156     0  20170410       16       140473       25
#
#    singer_popularity_rank
# 0                     183
# 1                      35
# 2                   25366
# 3                     431
# 4                   25366

# %%
df_play_log.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25632201 entries, 0 to 25632200
# Data columns (total 14 columns):
# uid                       object
# device                    object
# song_id                   object
# song_type                 object
# song_name                 object
# singer                    object
# play_time                 float64
# song_length               object
# label                     object
# date                      object
# count_x                   int64
# song_id_new               int64
# count_y                   int64
# singer_popularity_rank    int64
# dtypes: float64(1), int64(4), object(9)
# memory usage: 2.9+ GB

# %%
# get favorite songs info
popular_singers = df_play_log['singer_popularity_rank'].value_counts()[:200].index

popular_singers[100:110]
# Out:
# Int64Index([101, 102, 103, 104, 105, 106, 107, 108, 109, 110], dtype='int64')

# %% [markdown]
# ### reduce the size of the df_play_log
# In the following analysis, the original song_id, song_names and singer can be ommitted from the df_play_log, while the only information left is song_id_new, singer_popularity_rank.

# %%
df_play_log = df_play_log.drop(['song_name','singer','count_x','count_y'],axis = 1)
df_play_log.head()
# Out:
#          uid device   song_id song_type  play_time song_length label  \
# 0  168308107     ar    162455         0        296         296     0
# 1  168112765     ar   4393501         0        272           0     0
# 2  168274411     ar  22833011         0         24         156     0
# 3  168274411     ar    176292         0        333         334     0
# 4  168274411     ar  22833011         0        155         156     0
#
#        date  song_id_new  singer_popularity_rank
# 0  20170410          816                     183
# 1  20170410        13121                      35
# 2  20170410       140473                   25366
# 3  20170410         1171                     431
# 4  20170410       140473                   25366

# %%
df_play_log.drop(['song_id'], axis = 1, inplace = True)
df_play_log.head()
# Out:
#          uid device song_type  play_time song_length label      date  \
# 0  168308107     ar         0        296         296     0  20170410
# 1  168112765     ar         0        272           0     0  20170410
# 2  168274411     ar         0         24         156     0  20170410
# 3  168274411     ar         0        333         334     0  20170410
# 4  168274411     ar         0        155         156     0  20170410
#
#    song_id_new  singer_popularity_rank
# 0          816                     183
# 1        13121                      35
# 2       140473                   25366
# 3         1171                     431
# 4       140473                   25366

# %% [markdown]
# #### Save current data frames

# %%
play_file = '/Users/ZhijingYe/Desktop/data/output/reduced_play_log.csv'
df_play_log.to_csv(play_file,sep = '\t', mode = 'a', encoding = 'utf-8')

# %%
# also save into .pickle
play_file_pickle = '/Users/ZhijingYe/Desktop/data/output/reduced_play_log.pkl'
df_play_log.to_pickle(play_file_pickle)

# %%
# songs
song_file = '/Users/ZhijingYe/Desktop/data/output/songs.csv'
song_id_groupby_df.to_csv(song_file,sep = '\t', mode = 'a')

# %%
song_file_pickle = '/Users/ZhijingYe/Desktop/data/output/songs.pkl'
song_id_groupby_df.to_csv(song_file_pickle)

# %%
singer_file = '/Users/ZhijingYe/Desktop/data/output/singers.csv'
singer_groupby_df.to_csv(singer_file,sep = '\t', mode = 'a')

# %%
singer_file_pickle = '/Users/ZhijingYe/Desktop/data/output/singers.pkl'
singer_groupby_df.to_csv(singer_file_pickle)
